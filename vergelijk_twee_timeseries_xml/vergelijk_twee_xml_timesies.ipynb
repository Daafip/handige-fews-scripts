# %%
from pathlib import Path

# %%
path = Path.cwd() / "input"

# %%
dir_1 = path / "test1.xml"
dir_2 = path / "test2.xml"

# %%
import pandas as pd

import xml.etree.ElementTree as ET


def get_df(dir_):
    tree = ET.parse(dir_)
    root = tree.getroot()
    data = []
    for timeSeriesSet in root.findall(".//{http://www.wldelft.nl/fews}timeSeriesSet"):
        moduleInstanceId = timeSeriesSet.find(
            "{http://www.wldelft.nl/fews}moduleInstanceId"
        ).text
        valueType = timeSeriesSet.find("{http://www.wldelft.nl/fews}valueType").text
        parameterId = timeSeriesSet.find("{http://www.wldelft.nl/fews}parameterId").text
        locationSetId = timeSeriesSet.find(
            "{http://www.wldelft.nl/fews}locationSetId"
        ).text
        timeSeriesType = timeSeriesSet.find(
            "{http://www.wldelft.nl/fews}timeSeriesType"
        ).text
        timeStep = timeSeriesSet.find("{http://www.wldelft.nl/fews}timeStep").get(
            "unit"
        )
        readWriteMode = timeSeriesSet.find(
            "{http://www.wldelft.nl/fews}readWriteMode"
        ).text

        data.append(
            {
                "moduleInstanceId": moduleInstanceId,
                "valueType": valueType,
                "parameterId": parameterId,
                "locationSetId": locationSetId,
                "timeSeriesType": timeSeriesType,
                "timeStep": timeStep,
                "readWriteMode": readWriteMode,
            }
        )

    return root, pd.DataFrame(data).set_index(["moduleInstanceId", "parameterId"])

# %%
(root_1, df_1), (root_2, df_2) = get_df(dir_1), get_df(dir_2)

# %%
for col in df_1.columns:
    print(df_1[col].unique())
# Out:
# ['sample']
# ['LocationSet']
# ['external historical']
# ['nonequidistant']
# ['add originals']

# %%
print(
    f"in de versie 1 versie zitten {len(df_1)}, en in de {len(df_2)} versie 2"
)
# Out:
# in de versie 1 versie zitten 24466, en in de 26406 versie 2

# %%
both = df_1.join(df_2, lsuffix="_ont", rsuffix="_prepro", how="left").dropna()
len(both)
# Out:
# 24424

# %%
diff_1 = set(df_1.index).difference(both.index)

# %%
print(f"In Versie zitten {len(diff_1)} timeseries die niet in versie 2 zitten")
# Out:
# In Versie zitten 42 timeseries die niet in versie 2 zitten

# %%
df_1.loc[list(diff_1)]
# Out:
#                              valueType locationSetId       timeSeriesType  \
# moduleInstanceId parameterId
# Import_1         WNS14708       sample   LocationSet  external historical
#                  WNS14704       sample   LocationSet  external historical
# Import_2         WNS14700       sample   LocationSet  external historical
#                  WNS14704       sample   LocationSet  external historical
# Import_1         WNS15028       sample   LocationSet  external historical
#                  WNS14705       sample   LocationSet  external historical
#                  WNS14605       sample   LocationSet  external historical
#                  WNS14710       sample   LocationSet  external historical
# Import_2         WNS14715       sample   LocationSet  external historical
# Import_1         WNS14694       sample   LocationSet  external historical
#                  WNS14702       sample   LocationSet  external historical
#                  WNS14604       sample   LocationSet  external historical
# Import_2         WNS14701       sample   LocationSet  external historical
#                  WNS14695       sample   LocationSet  external historical
# Import_1         WNS14618       sample   LocationSet  external historical
#                  WNS14706       sample   LocationSet  external historical
#                  WNS14699       sample   LocationSet  external historical
# Import_2         WNS14706       sample   LocationSet  external historical
#                  WNS14699       sample   LocationSet  external historical
#                  WNS14618       sample   LocationSet  external historical
#                  WNS14708       sample   LocationSet  external historical
# Import_1         WNS14703       sample   LocationSet  external historical
# Import_2         WNS14703       sample   LocationSet  external historical
# Import_1         WNS14707       sample   LocationSet  external historical
# Import_2         WNS14707       sample   LocationSet  external historical
# Import_1         WNS14696       sample   LocationSet  external historical
# Import_2         WNS14696       sample   LocationSet  external historical
#                  WNS15028       sample   LocationSet  external historical
#                  WNS14705       sample   LocationSet  external historical
# Import_1         WNS14614       sample   LocationSet  external historical
# Import_2         WNS14614       sample   LocationSet  external historical
# Import_1         WNS14700       sample   LocationSet  external historical
# Import_2         WNS14605       sample   LocationSet  external historical
#                  WNS14710       sample   LocationSet  external historical
# Import_1         WNS14715       sample   LocationSet  external historical
# Import_2         WNS14694       sample   LocationSet  external historical
# Import_1         WNS14709       sample   LocationSet  external historical
# Import_2         WNS14702       sample   LocationSet  external historical
#                  WNS14709       sample   LocationSet  external historical
#                  WNS14604       sample   LocationSet  external historical
# Import_1         WNS14701       sample   LocationSet  external historical
#                  WNS14695       sample   LocationSet  external historical
#
#                                     timeStep  readWriteMode
# moduleInstanceId parameterId
# Import_1         WNS14708     nonequidistant  add originals
#                  WNS14704     nonequidistant  add originals
# Import_2         WNS14700     nonequidistant  add originals
#                  WNS14704     nonequidistant  add originals
# Import_1         WNS15028     nonequidistant  add originals
#                  WNS14705     nonequidistant  add originals
#                  WNS14605     nonequidistant  add originals
#                  WNS14710     nonequidistant  add originals
# Import_2         WNS14715     nonequidistant  add originals
# Import_1         WNS14694     nonequidistant  add originals
#                  WNS14702     nonequidistant  add originals
#                  WNS14604     nonequidistant  add originals
# Import_2         WNS14701     nonequidistant  add originals
#                  WNS14695     nonequidistant  add originals
# Import_1         WNS14618     nonequidistant  add originals
#                  WNS14706     nonequidistant  add originals
#                  WNS14699     nonequidistant  add originals
# Import_2         WNS14706     nonequidistant  add originals
#                  WNS14699     nonequidistant  add originals
#                  WNS14618     nonequidistant  add originals
#                  WNS14708     nonequidistant  add originals
# Import_1         WNS14703     nonequidistant  add originals
# Import_2         WNS14703     nonequidistant  add originals
# Import_1         WNS14707     nonequidistant  add originals
# Import_2         WNS14707     nonequidistant  add originals
# Import_1         WNS14696     nonequidistant  add originals
# Import_2         WNS14696     nonequidistant  add originals
#                  WNS15028     nonequidistant  add originals
#                  WNS14705     nonequidistant  add originals
# Import_1         WNS14614     nonequidistant  add originals
# Import_2         WNS14614     nonequidistant  add originals
# Import_1         WNS14700     nonequidistant  add originals
# Import_2         WNS14605     nonequidistant  add originals
#                  WNS14710     nonequidistant  add originals
# Import_1         WNS14715     nonequidistant  add originals
# Import_2         WNS14694     nonequidistant  add originals
# Import_1         WNS14709     nonequidistant  add originals
# Import_2         WNS14702     nonequidistant  add originals
#                  WNS14709     nonequidistant  add originals
#                  WNS14604     nonequidistant  add originals
# Import_1         WNS14701     nonequidistant  add originals
#                  WNS14695     nonequidistant  add originals

# %%
output_file = "filtered_timeseries.xml"

def output_to_xml(root, diff_df, output_file):
    indexes = []
    for timeSeriesSet in root.findall(".//{http://www.wldelft.nl/fews}timeSeriesSet"):
        moduleInstanceId = timeSeriesSet.find("{http://www.wldelft.nl/fews}moduleInstanceId").text
        parameterId = timeSeriesSet.find("{http://www.wldelft.nl/fews}parameterId").text
        if (moduleInstanceId, parameterId) in diff_df:
            indexes.append((moduleInstanceId, parameterId))

    kwargs={"version": "1.1", 
    "xmlns": "http://www.wldelft.nl/fews", 
    "xmlns:xsi":"http://www.w3.org/2001/XMLSchema-instance", 
    "xsi:schemaLocation":"http://www.wldelft.nl/fews http://fews.wldelft.nl/schemas/version1.0/validationRuleSets.xsd"}
    new_root =  ET.Element('validationRuleSets', **kwargs)

    validation_rule_set = ET.SubElement(new_root, 'validationRuleSet', validationRuleSetId="ExtremeValue", timeZone="CET")
    log_level = ET.SubElement(validation_rule_set, 'logLevel')
    log_level.text = 'DEBUG'
    extreme_values_functions = ET.SubElement(validation_rule_set, 'extremeValuesFunctions')
    ET.SubElement(extreme_values_functions, 'hardMax', constantLimit="@H_MAX@")
    ET.SubElement(extreme_values_functions, 'hardMin', constantLimit="@H_MIN@")
    ET.SubElement(extreme_values_functions, 'softMax', constantLimit="@S_MAX@")
    ET.SubElement(extreme_values_functions, 'softMin', constantLimit="@S_MIN@")

    for moduleInstanceId, parameterId in indexes:
        for timeSeriesSet in root.findall(".//{http://www.wldelft.nl/fews}timeSeriesSet"):
            if (
                timeSeriesSet.find("{http://www.wldelft.nl/fews}moduleInstanceId").text == moduleInstanceId
                and timeSeriesSet.find("{http://www.wldelft.nl/fews}parameterId").text == parameterId
            ):
                # new_root.append(timeSeriesSet)
                time_series_set = ET.SubElement(validation_rule_set, 'timeSeriesSet')
                for name in ['moduleInstanceId','valueType', 'parameterId', 'locationSetId', 'timeSeriesType', 'timeStep',  'readWriteMode']: 
                    ET.SubElement(time_series_set, name).text = timeSeriesSet.find("{http://www.wldelft.nl/fews}"+f"{name}").text

    new_tree = ET.ElementTree(new_root)
    new_tree.write(output_file, default_namespace="")

# %%
output_to_xml(root_1, diff_1, output_file="diff_1.xml")

# %%
diff_2 = set(df_2.index).difference(both.index)

# %%
print(f"In versie 2 zitten {len(diff_2)} timeseries die niet in versie 1 zitten")
# Out:
# In versie 2 zitten 1982 timeseries die niet in versie 1 zitten

# %%
diff_2
# Out:
# {('Import_2', 'WNS14140'),
#  ('Import_2', 'TTSWDE[n]'),
#  ('Import_2', 'WNS13733'),
#  ('Import_1', 'WNS13895'),
#  ('Import_1', 'WNS13978'),
#  ('Import_1', 'WNS13716'),
#  ('Import_1', 'WNS13502'),
#  ('Import_1', 'WNS13712'),
#  ('Import_2', 'WNS13159'),
#  ('Import_2', 'WNS14102'),
#  ('Import_1', 'WNS13998'),
#  ('Import_1', 'WNS13248'),
#  ('Import_1', 'WNS13923'),
#  ('Import_2', 'WNS13292'),
#  ('Import_2', 'WNS13151'),
#  ('Import_2', 'WNS14131'),
#  ('Import_1', 'WNS13549'),
#  ('Import_1', 'WNS13990'),
#  ('Import_2', 'WNS13906'),
#  ('Import_2', 'WNS13351'),
#  ('Import_2', 'WNS13734'),
#  ('Import_1', 'WNS14172'),
#  ('Import_1', 'WNS13420'),
#  ('Import_2', 'WNS13787'),
#  ('Import_1', 'WNS13166'),
#  ('Import_2', 'WNS13433'),
#  ('Import_1', 'WNS13230'),
#  ('Import_1', 'WNS13480'),
#  ('Import_1', 'WNS14010'),
#  ('Import_2', 'WNS13797'),
#  ('Import_1', 'WNS13596'),
#  ('Import_2', 'TTSWDE[n/ha]'),
#  ('Import_1', 'WNS13818'),
#  ('Import_1', 'WNS13873'),
#  ('Import_2', 'TSTNDWDE[ug/l]'),
#  ('Import_1', 'WNS14005'),
#  ('Import_2', 'TSTNDWDE[ng/l]'),
#  ('Import_1', 'WNS13777'),
#  ('Import_2', 'WNS13277'),
#  ('Import_2', 'WNS13823'),
#  ('Import_1', 'WNS14035'),
#  ('Import_2', 'WNS13448'),
#  ('Import_2', 'WNS13413'),
#  ('Import_1', 'WNS13498'),
#  ('Import_2', 'WNS13779'),
#  ('Import_1', 'WNS13350'),
#  ('Import_1', 'WNS13904'),
#  ('Import_2', 'WNS14013'),
#  ('Import_1', 'WNS13270'),
#  ('Import_1', 'WNS13437'),
#  ('Import_1', 'WNS13947'),
#  ('Import_2', 'WNS13199'),
#  ('Import_2', 'WNS14032'),
#  ('Import_2', 'WNS13139'),
#  ('Import_2', 'WNS13260'),
#  ('Import_1', 'WNS13407'),
#  ('Import_1', 'WNS13354'),
#  ('Import_2', 'WNS13196'),
#  ('Import_2', 'WNS13557'),
#  ('Import_1', 'WNS13957'),
#  ('Import_1', 'WNS13570'),
#  ('Import_1', 'WNS14142'),
#  ('Import_1', 'WNS13820'),
#  ('Import_2', 'WNS13760'),
#  ('Import_2', 'WNS13505'),
#  ('Import_2', 'WNS13550'),
#  ('Import_2', 'WNS13340'),
#  ('Import_1', 'WNS13755'),
#  ('Import_1', 'WNS13673'),
#  ('Import_2', 'WNS14152'),
#  ('Import_2', 'WNS13273'),
#  ('Import_1', 'WNS13414'),
#  ('Import_2', 'WNS13663'),
#  ('Import_1', 'WNS13580'),
#  ('Import_1', 'WNS13226'),
#  ('Import_2', 'WNS13285'),
#  ('Import_2', 'WNS13911'),
#  ('Import_1', 'WNS13757'),
#  ('Import_2', 'WNS13988'),
#  ('Import_1', 'WNS13684'),
#  ('Import_1', 'WNS13855'),
#  ('Import_2', 'WNS13535'),
#  ('Import_2', 'WNS13249'),
#  ('Import_1', 'WNS13579'),
#  ('Import_2', 'WNS14007'),
#  ('Import_2', 'WNS13812'),
#  ('Import_2', 'WNS13887'),
#  ('Import_1', 'WNS14155'),
#  ('Import_2', 'WNS13716'),
#  ('Import_1', 'WNS14027'),
#  ('Import_1', 'WNS13219'),
#  ('Import_1', 'WNS13775'),
#  ('Import_2', 'WNS13374'),
#  ('Import_2', 'WNS13924'),
#  ('Import_1', 'WNS13847'),
#  ('Import_1', 'WNS13791'),
#  ('Import_2', 'WNS13705'),
#  ('Import_2', 'WNS13998'),
#  ('Import_1', 'WNS13695'),
#  ('Import_2', 'WNS13248'),
#  ('Import_2', 'WNS13539'),
#  ('Import_2', 'WNS13923'),
#  ('Import_2', 'WNS13254'),
#  ('Import_1', 'WNS13997'),
#  ('Import_2', 'WNS13537'),
#  ('Import_1', 'WNS13864'),
#  ('Import_2', 'WNS13990'),
#  ('Import_2', 'WNS13348'),
#  ('Import_1', 'WNS13868'),
#  ('Import_1', 'WNS13689'),
#  ('Import_2', 'WNS14172'),
#  ('Import_1', 'WNS13266'),
#  ('Import_1', 'WNS13880'),
#  ('Import_2', 'WNS13642'),
#  ('Import_1', 'WNS13562'),
#  ('Import_1', 'WNS13157'),
#  ('Import_1', 'WNS13321'),
#  ('Import_2', 'WNS14010'),
#  ('Import_1', 'WNS13506'),
#  ('Import_1', 'TTSWDE[mg/l]'),
#  ('Import_1', 'WNS13294'),
#  ('Import_2', 'WNS13818'),
#  ('Import_2', 'WNS13873'),
#  ('Import_2', 'WNS13310'),
#  ('Import_1', 'WNS13311'),
#  ('Import_2', 'WNS14035'),
#  ('Import_1', 'WNS13685'),
#  ('Import_2', 'WNS13951'),
#  ('Import_2', 'WNS13928'),
#  ('Import_1', 'WNS13702'),
#  ('Import_1', 'WNS14136'),
#  ('Import_1', 'WNS13287'),
#  ('Import_1', 'WNS13966'),
#  ('Import_1', 'WNS13849'),
#  ('Import_1', 'WNS13662'),
#  ('Import_1', 'WNS13905'),
#  ('Import_2', 'WNS13222'),
#  ('Import_1', 'WNS13637'),
#  ('Import_1', 'WNS13302'),
#  ('Import_2', 'WNS13407'),
#  ('Import_1', 'WNS13890'),
#  ('Import_1', 'WNS13644'),
#  ('Import_2', 'WNS13224'),
#  ('Import_1', 'WNS14015'),
#  ('Import_2', 'WNS13898'),
#  ('Import_2', 'WNS13972'),
#  ('Import_1', 'WNS13154'),
#  ('Import_1', 'WNS13946'),
#  ('Import_1', 'WNS13656'),
#  ('Import_2', 'WNS13349'),
#  ('Import_1', 'WNS13386'),
#  ('Import_2', 'WNS13316'),
#  ('Import_1', 'WNS14126'),
#  ('Import_1', 'WNS13167'),
#  ('Import_2', 'WNS14139'),
#  ('Import_1', 'WNS13599'),
#  ('Import_1', 'WNS13482'),
#  ('Import_2', 'WNS13673'),
#  ('Import_2', 'WNS13414'),
#  ('Import_2', 'WNS13226'),
#  ('Import_1', 'WNS13846'),
#  ('Import_1', 'WNS13726'),
#  ('Import_1', 'WNS14030'),
#  ('Import_1', 'WNS13790'),
#  ('Import_2', 'WNS13579'),
#  ('Import_2', 'TTSWDE[ng/l]'),
#  ('Import_1', 'WNS13816'),
#  ('Import_2', 'WNS14155'),
#  ('Import_1', 'WNS13731'),
#  ('Import_2', 'WNS13481'),
#  ('Import_2', 'WNS14027'),
#  ('Import_2', 'WNS13219'),
#  ('Import_2', 'WNS13775'),
#  ('Import_1', 'WNS13595'),
#  ('Import_1', 'WNS13467'),
#  ('Import_1', 'WNS13593'),
#  ('Import_1', 'WNS13483'),
#  ('Import_2', 'WNS13695'),
#  ('Import_1', 'WNS13485'),
#  ('Import_1', 'WNS13718'),
#  ('Import_2', 'WNS13164'),
#  ('Import_2', 'WNS13319'),
#  ('Import_1', 'WNS13613'),
#  ('Import_1', 'WNS13756'),
#  ('Import_2', 'WNS13864'),
#  ('Import_2', 'WNS13586'),
#  ('Import_1', 'WNS13360'),
#  ('Import_2', 'WNS13468'),
#  ('Import_2', 'WNS13504'),
#  ('Import_2', 'WNS13639'),
#  ('Import_1', 'WNS13721'),
#  ('Import_2', 'WNS13266'),
#  ('Import_2', 'WNS13880'),
#  ('Import_2', 'WNS13562'),
#  ('Import_1', 'WNS13952'),
#  ('Import_2', 'WNS13321'),
#  ('Import_2', 'WNS13294'),
#  ('Import_1', 'WNS13342'),
#  ('Import_2', 'WNS13585'),
#  ('Import_1', 'WNS13408'),
#  ('Import_2', 'WNS13311'),
#  ('Import_1', 'WNS13772'),
#  ('Import_2', 'WNS13702'),
#  ('Import_2', 'WNS14136'),
#  ('Import_1', 'WNS13591'),
#  ('Import_2', 'WNS13966'),
#  ('Import_2', 'WNS13849'),
#  ('Import_1', 'WNS13866'),
#  ('Import_1', 'WNS13341'),
#  ('Import_1', 'WNS13356'),
#  ('Import_1', 'WNS13418'),
#  ('Import_1', 'WNS14025'),
#  ('Import_2', 'WNS13905'),
#  ('Import_2', 'WNS13288'),
#  ('Import_2', 'WNS13637'),
#  ('Import_2', 'WNS13302'),
#  ('Import_1', 'WNS13329'),
#  ('Import_2', 'WNS13687'),
#  ('Import_2', 'WNS13741'),
#  ('Import_1', 'TTSWDE[%]'),
#  ('Import_2', 'WNS14161'),
#  ('Import_2', 'WNS13890'),
#  ('Import_2', 'WNS13526'),
#  ('Import_1', 'WNS13935'),
#  ('Import_1', 'WNS13158'),
#  ('Import_2', 'WNS13644'),
#  ('Import_2', 'WNS14015'),
#  ('Import_1', 'WNS13753'),
#  ('Import_2', 'WNS13154'),
#  ('Import_2', 'WNS13946'),
#  ('Import_2', 'WNS13807'),
#  ('Import_1', 'WNS13304'),
#  ('Import_2', 'WNS13669'),
#  ('Import_1', 'WNS13333'),
#  ('Import_1', 'WNS13400'),
#  ('Import_2', 'WNS13386'),
#  ('Import_1', 'WNS13429'),
#  ('Import_1', 'WNS13977'),
#  ('Import_2', 'WNS13167'),
#  ('Import_1', 'WNS14145'),
#  ('Import_1', 'WNS13149'),
#  ('Import_2', 'WNS13482'),
#  ('Import_1', 'WNS13619'),
#  ('Import_1', 'WNS13959'),
#  ('Import_1', 'WNS13738'),
#  ('Import_2', 'WNS13846'),
#  ('Import_1', 'WNS13896'),
#  ('Import_2', 'WNS13726'),
#  ('Import_2', 'WNS13393'),
#  ('Import_1', 'WNS13512'),
#  ('Import_1', 'WNS13263'),
#  ('Import_2', 'WNS14167'),
#  ('Import_2', 'WNS13936'),
#  ('Import_1', 'WNS13392'),
#  ('Import_1', 'WNS13344'),
#  ('Import_1', 'WNS13944'),
#  ('Import_1', 'WNS13540'),
#  ('Import_1', 'WNS13441'),
#  ('Import_1', 'WNS13752'),
#  ('Import_1', 'WNS13920'),
#  ('Import_1', 'WNS13711'),
#  ('Import_1', 'WNS13918'),
#  ('Import_2', 'WNS13786'),
#  ('Import_1', 'WNS13857'),
#  ('Import_2', 'WNS13614'),
#  ('Import_2', 'WNS14004'),
#  ('Import_2', 'WNS13483'),
#  ('Import_2', 'WNS13514'),
#  ('Import_1', 'WNS13930'),
#  ('Import_2', 'WNS13968'),
#  ('Import_1', 'WNS13290'),
#  ('Import_1', 'WNS13163'),
#  ('Import_1', 'WNS14014'),
#  ('Import_2', 'WNS13554'),
#  ('Import_2', 'WNS14162'),
#  ('Import_1', 'WNS14109'),
#  ('Import_1', 'WNS13856'),
#  ('Import_2', 'WNS13769'),
#  ('Import_1', 'WNS13879'),
#  ('Import_1', 'WNS13297'),
#  ('Import_1', 'WNS13661'),
#  ('Import_1', 'WNS13903'),
#  ('Import_2', 'WNS14153'),
#  ('Import_1', 'WNS13885'),
#  ('Import_2', 'WNS13360'),
#  ('Import_1', 'WNS13844'),
#  ('Import_2', 'WNS13952'),
#  ('Import_1', 'WNS13942'),
#  ('Import_1', 'WNS13326'),
#  ('Import_2', 'WNS13342'),
#  ('Import_2', 'WNS13132'),
#  ('Import_1', 'WNS13801'),
#  ('Import_1', 'WNS13860'),
#  ('Import_1', 'WNS13262'),
#  ('Import_2', 'WNS13499'),
#  ('Import_2', 'WNS13668'),
#  ('Import_2', 'WNS13699'),
#  ('Import_1', 'WNS13811'),
#  ('Import_1', 'WNS13466'),
#  ('Import_2', 'WNS13825'),
#  ('Import_1', 'WNS13486'),
#  ('Import_1', 'WNS14055'),
#  ('Import_1', 'TSTNDODL[DIMSLS]'),
#  ('Import_1', 'WNS13228'),
#  ('Import_2', 'WNS13418'),
#  ('Import_2', 'WNS13688'),
#  ('Import_2', 'WNS14039'),
#  ('Import_1', 'WNS13473'),
#  ('Import_1', 'WNS13257'),
#  ('Import_2', 'WNS13329'),
#  ('Import_1', 'WNS13815'),
#  ('Import_1', 'WNS13315'),
#  ('Import_1', 'WNS13220'),
#  ('Import_2', 'WNS13795'),
#  ('Import_2', 'WNS13332'),
#  ('Import_1', 'WNS14021'),
#  ('Import_1', 'WNS13255'),
#  ('Import_1', 'WNS14103'),
#  ('Import_2', 'WNS13753'),
#  ('Import_2', 'WNS13892'),
#  ('Import_1', 'WNS13491'),
#  ('Import_1', 'WNS13177'),
#  ('Import_2', 'WNS13694'),
#  ('Import_1', 'TTSODL[DIMSLS]'),
#  ('Import_2', 'WNS13333'),
#  ('Import_2', 'WNS13754'),
#  ('Import_1', 'WNS13872'),
#  ('Import_2', 'WNS13330'),
#  ('Import_2', 'WNS13646'),
#  ('Import_2', 'WNS13429'),
#  ('Import_1', 'WNS14117'),
#  ('Import_2', 'WNS14130'),
#  ('Import_1', 'WNS13320'),
#  ('Import_2', 'WNS13293'),
#  ('Import_1', 'WNS13680'),
#  ('Import_2', 'WNS13619'),
#  ('Import_1', 'WNS13651'),
#  ('Import_2', 'WNS13246'),
#  ('Import_2', 'WNS13490'),
#  ('Import_1', 'WNS13501'),
#  ('Import_1', 'WNS13762'),
#  ('Import_1', 'WNS13655'),
#  ('Import_2', 'WNS13512'),
#  ('Import_2', 'WNS13263'),
#  ('Import_1', 'WNS13475'),
#  ('Import_2', 'WNS13392'),
#  ('Import_2', 'WNS14044'),
#  ('Import_2', 'WNS13344'),
#  ('Import_1', 'WNS13425'),
#  ('Import_1', 'WNS13897'),
#  ('Import_1', 'WNS13700'),
#  ('Import_1', 'WNS13647'),
#  ('Import_2', 'WNS13622'),
#  ('Import_1', 'WNS13840'),
#  ('Import_2', 'WNS13174'),
#  ('Import_2', 'WNS13920'),
#  ('Import_1', 'WNS13336'),
#  ('Import_2', 'WNS13711'),
#  ('Import_1', 'WNS13474'),
#  ('Import_2', 'WNS13450'),
#  ('Import_1', 'WNS13650'),
#  ('Import_1', 'WNS13912'),
#  ('Import_1', 'WNS14165'),
#  ('Import_2', 'WNS14170'),
#  ('Import_1', 'WNS13723'),
#  ('Import_2', 'WNS13930'),
#  ('Import_2', 'WNS13973'),
#  ('Import_1', 'WNS13737'),
#  ('Import_2', 'WNS14014'),
#  ('Import_2', 'WNS13269'),
#  ('Import_2', 'WNS14109'),
#  ('Import_1', 'WNS13500'),
#  ('Import_1', 'WNS13472'),
#  ('Import_1', 'WNS13817'),
#  ('Import_2', 'WNS13856'),
#  ('Import_2', 'WNS13511'),
#  ('Import_2', 'WNS13435'),
#  ('Import_1', 'WNS13727'),
#  ('Import_1', 'WNS13989'),
#  ('Import_2', 'WNS13903'),
#  ('Import_1', 'WNS13428'),
#  ('Import_2', 'WNS13460'),
#  ('Import_1', 'WNS13743'),
#  ('Import_2', 'WNS13577'),
#  ('Import_2', 'WNS13942'),
#  ('Import_2', 'WNS13666'),
#  ('Import_2', 'WNS13326'),
#  ('Import_2', 'WNS13939'),
#  ('Import_1', 'WNS13803'),
#  ('Import_2', 'WNS13801'),
#  ('Import_2', 'WNS13394'),
#  ('Import_1', 'WNS13607'),
#  ('Import_1', 'WNS14037'),
#  ('Import_1', 'WNS13162'),
#  ('Import_2', 'WNS13811'),
#  ('Import_1', 'WNS13571'),
#  ('Import_1', 'WNS13369'),
#  ('Import_2', 'WNS13486'),
#  ('Import_1', 'WNS13380'),
#  ('Import_2', 'TSTNDODL[DIMSLS]'),
#  ('Import_2', 'WNS13657'),
#  ('Import_1', 'WNS13191'),
#  ('Import_2', 'WNS13636'),
#  ('Import_2', 'WNS13582'),
#  ('Import_2', 'WNS13632'),
#  ('Import_2', 'WNS13473'),
#  ('Import_2', 'WNS13257'),
#  ('Import_1', 'WNS13507'),
#  ('Import_2', 'WNS14118'),
#  ('Import_2', 'WNS13761'),
#  ('Import_2', 'WNS14021'),
#  ('Import_1', 'WNS13725'),
#  ('Import_1', 'WNS13643'),
#  ('Import_1', 'WNS13279'),
#  ('Import_1', 'WNS13143'),
#  ('Import_2', 'WNS13621'),
#  ('Import_2', 'WNS14103'),
#  ('Import_2', 'WNS13447'),
#  ('Import_1', 'Ebeo_Oev[DIMSLS]'),
#  ('Import_2', 'WNS13177'),
#  ('Import_2', 'TTSODL[DIMSLS]'),
#  ('Import_1', 'WNS13487'),
#  ('Import_1', 'WNS14150'),
#  ('Import_1', 'WNS13404'),
#  ('Import_1', 'WNS13496'),
#  ('Import_2', 'WNS13308'),
#  ('Import_1', 'WNS13956'),
#  ('Import_1', 'WNS13289'),
#  ('Import_1', 'WNS13234'),
#  ('Import_2', 'WNS13950'),
#  ('Import_2', 'WNS13680'),
#  ('Import_1', 'WNS13877'),
#  ('Import_2', 'WNS13651'),
#  ('Import_2', 'WNS13301'),
#  ('Import_2', 'WNS13419'),
#  ('Import_1', 'WNS13964'),
#  ('Import_1', 'WNS13371'),
#  ('Import_2', 'WNS13501'),
#  ('Import_2', 'WNS14108'),
#  ('Import_2', 'WNS13908'),
#  ('Import_1', 'WNS13476'),
#  ('Import_1', 'WNS13783'),
#  ('Import_2', 'WNS13475'),
#  ('Import_2', 'WNS13421'),
#  ('Import_2', 'WNS13425'),
#  ('Import_2', 'WNS13897'),
#  ('Import_2', 'WNS13746'),
#  ('Import_2', 'WNS13700'),
#  ('Import_2', 'WNS13547'),
#  ('Import_2', 'WNS13647'),
#  ('Import_1', 'WNS13605'),
#  ('Import_2', 'WNS13840'),
#  ('Import_1', 'WNS13704'),
#  ('Import_2', 'WNS13443'),
#  ('Import_1', 'WNS13835'),
#  ('Import_2', 'WNS13474'),
#  ('Import_1', 'WNS13558'),
#  ('Import_2', 'WNS13370'),
#  ('Import_2', 'WNS13411'),
#  ('Import_1', 'WNS13771'),
#  ('Import_2', 'WNS13650'),
#  ('Import_1', 'WNS13589'),
#  ('Import_2', 'WNS14031'),
#  ('Import_2', 'WNS13723'),
#  ('Import_2', 'WNS14000'),
#  ('Import_2', 'WNS14160'),
#  ('Import_1', 'WNS14154'),
#  ('Import_2', 'WNS13472'),
#  ('Import_2', 'WNS13500'),
#  ('Import_1', 'WNS13172'),
#  ('Import_2', 'WNS13817'),
#  ('Import_2', 'WNS13727'),
#  ('Import_1', 'WNS13395'),
#  ('Import_2', 'WNS13989'),
#  ('Import_1', 'WNS13529'),
#  ('Import_2', 'WNS14129'),
#  ('Import_1', 'WNS13588'),
#  ('Import_2', 'WNS13183'),
#  ('Import_1', 'WNS13524'),
#  ('Import_1', 'WNS14148'),
#  ('Import_1', 'WNS13552'),
#  ('Import_2', 'WNS13743'),
#  ('Import_2', 'WNS13367'),
#  ('Import_2', 'WNS13982'),
#  ('Import_1', 'WNS13454'),
#  ('Import_1', 'WNS13382'),
#  ('Import_2', 'WNS13854'),
#  ('Import_2', 'WNS13803'),
#  ('Import_1', 'WNS13280'),
#  ('Import_1', 'WNS13424'),
#  ('Import_1', 'WNS13629'),
#  ('Import_2', 'WNS13607'),
#  ('Import_2', 'WNS13369'),
#  ('Import_1', 'WNS13747'),
#  ('Import_2', 'WNS13764'),
#  ('Import_1', 'WNS13567'),
#  ('Import_1', 'WNS13859'),
#  ('Import_2', 'WNS13191'),
#  ('Import_2', 'WNS14028'),
#  ('Import_2', 'TTSWDE[kg/ha]'),
#  ('Import_2', 'WNS13638'),
#  ('Import_1', 'WNS13155'),
#  ('Import_1', 'WNS13416'),
#  ('Import_2', 'WNS13725'),
#  ('Import_1', 'WNS13745'),
#  ('Import_2', 'WNS13279'),
#  ('Import_1', 'WNS13874'),
#  ('Import_2', 'WNS14125'),
#  ('Import_2', 'WNS13489'),
#  ('Import_2', 'Ebeo_Oev[DIMSLS]'),
#  ('Import_1', 'WNS13399'),
#  ('Import_2', 'WNS13869'),
#  ('Import_2', 'WNS14150'),
#  ('Import_1', 'WNS13971'),
#  ('Import_2', 'WNS13264'),
#  ('Import_1', 'WNS13722'),
#  ('Import_1', 'WNS13148'),
#  ('Import_2', 'WNS13956'),
#  ('Import_2', 'WNS13404'),
#  ('Import_1', 'WNS13278'),
#  ('Import_1', 'WNS14101'),
#  ('Import_2', 'WNS13268'),
#  ('Import_2', 'WNS13877'),
#  ('Import_2', 'WNS13964'),
#  ('Import_2', 'WNS13371'),
#  ('Import_2', 'WNS13477'),
#  ('Import_1', 'WNS13871'),
#  ('Import_1', 'WNS13389'),
#  ('Import_1', 'WNS13390'),
#  ('Import_2', 'WNS13783'),
#  ('Import_1', 'WNS13631'),
#  ('Import_1', 'WNS13604'),
#  ('Import_2', 'WNS13832'),
#  ('Import_1', 'WNS13373'),
#  ('Import_1', 'WNS13748'),
#  ('Import_2', 'WNS13917'),
#  ('Import_1', 'WNS13555'),
#  ('Import_1', 'WNS13185'),
#  ('Import_1', 'WNS13841'),
#  ('Import_1', 'WNS14008'),
#  ('Import_1', 'WNS13945'),
#  ('Import_2', 'WNS13704'),
#  ('Import_1', 'WNS13744'),
#  ('Import_1', 'WNS13851'),
#  ('Import_2', 'WNS13835'),
#  ('Import_2', 'WNS13558'),
#  ('Import_1', 'WNS13377'),
#  ('Import_1', 'WNS13703'),
#  ('Import_2', 'WNS13565'),
#  ('Import_1', 'WNS13938'),
#  ('Import_1', 'WNS13364'),
#  ('Import_2', 'WNS13589'),
#  ('Import_1', 'WNS13765'),
#  ('Import_2', 'WNS13338'),
#  ('Import_1', 'WNS13182'),
#  ('Import_1', 'WNS13434'),
#  ('Import_2', 'WNS13679'),
#  ('Import_1', 'WNS13649'),
#  ('Import_2', 'WNS13588'),
#  ('Import_1', 'WNS13464'),
#  ('Import_2', 'WNS13457'),
#  ('Import_1', 'WNS14100'),
#  ('Import_1', 'WNS13405'),
#  ('Import_1', 'WNS13929'),
#  ('Import_2', 'WNS13274'),
#  ('Import_2', 'WNS14038'),
#  ('Import_2', 'WNS13171'),
#  ('Import_2', 'WNS13454'),
#  ('Import_1', 'WNS13623'),
#  ('Import_2', 'WNS13461'),
#  ('Import_1', 'WNS13843'),
#  ('Import_2', 'WNS13280'),
#  ('Import_1', 'WNS13525'),
#  ('Import_2', 'WNS13640'),
#  ('Import_2', 'WNS13937'),
#  ('Import_2', 'WNS13994'),
#  ('Import_1', 'WNS13462'),
#  ('Import_2', 'WNS13195'),
#  ('Import_2', 'TSTNDWDE[mg/l]'),
#  ('Import_2', 'WNS13629'),
#  ('Import_2', 'WNS13513'),
#  ('Import_2', 'WNS14020'),
#  ('Import_2', 'WNS13774'),
#  ('Import_2', 'WNS13859'),
#  ('Import_2', 'WNS14023'),
#  ('Import_1', 'WNS13176'),
#  ('Import_2', 'WNS13899'),
#  ('Import_2', 'WNS13541'),
#  ('Import_2', 'WNS13416'),
#  ('Import_2', 'WNS13822'),
#  ('Import_2', 'WNS14128'),
#  ('Import_1', 'WNS13932'),
#  ('Import_1', 'WNS13862'),
#  ('Import_1', 'WNS13309'),
#  ('Import_2', 'WNS13406'),
#  ('Import_1', 'WNS14045'),
#  ('Import_2', 'WNS13399'),
#  ('Import_1', 'WNS13378'),
#  ('Import_1', 'WNS13714'),
#  ('Import_2', 'WNS13148'),
#  ('Import_1', 'WNS13165'),
#  ('Import_2', 'WNS13612'),
#  ('Import_2', 'WNS14101'),
#  ('Import_2', 'WNS13144'),
#  ('Import_1', 'WNS13237'),
#  ('Import_2', 'WNS13659'),
#  ('Import_1', 'WNS13667'),
#  ('Import_2', 'WNS13283'),
#  ('Import_1', 'WNS13261'),
#  ('Import_2', 'WNS13992'),
#  ('Import_2', 'WNS13995'),
#  ('Import_1', 'WNS13532'),
#  ('Import_1', 'WNS14138'),
#  ('Import_1', 'WNS13999'),
#  ('Import_2', 'WNS13390'),
#  ('Import_2', 'WNS13604'),
#  ('Import_1', 'WNS13357'),
#  ('Import_1', 'WNS14104'),
#  ('Import_1', 'WNS13522'),
#  ('Import_1', 'WNS13352'),
#  ('Import_1', 'WNS13925'),
#  ('Import_2', 'WNS13841'),
#  ('Import_2', 'WNS13881'),
#  ('Import_1', 'WNS13833'),
#  ('Import_2', 'WNS13744'),
#  ('Import_2', 'WNS13851'),
#  ('Import_2', 'WNS13377'),
#  ('Import_2', 'WNS13703'),
#  ('Import_2', 'WNS13576'),
#  ('Import_1', 'WNS13889'),
#  ('Import_1', 'WNS13221'),
#  ('Import_2', 'WNS13805'),
#  ('Import_1', 'WNS13804'),
#  ('Import_2', 'WNS13765'),
#  ('Import_1', 'WNS13821'),
#  ('Import_1', 'WNS13735'),
#  ('Import_1', 'WNS14043'),
#  ('Import_2', 'WNS13442'),
#  ('Import_1', 'WNS13323'),
#  ('Import_1', 'WNS13231'),
#  ('Import_2', 'WNS13649'),
#  ('Import_1', 'WNS13732'),
#  ('Import_1', 'WNS13444'),
#  ('Import_1', 'WNS13784'),
#  ('Import_1', 'WNS13870'),
#  ('Import_1', 'WNS13827'),
#  ('Import_2', 'WNS13405'),
#  ('Import_1', 'WNS13188'),
#  ('Import_1', 'WNS13327'),
#  ('Import_1', 'WNS13306'),
#  ('Import_2', 'WNS13627'),
#  ('Import_2', 'WNS13780'),
#  ('Import_1', 'WNS13488'),
#  ('Import_1', 'WNS13379'),
#  ('Import_1', 'WNS13861'),
#  ('Import_2', 'WNS13553'),
#  ('Import_1', 'WNS13810'),
#  ('Import_2', 'WNS13623'),
#  ('Import_1', 'WNS14114'),
#  ('Import_1', 'WNS14123'),
#  ('Import_2', 'WNS13843'),
#  ('Import_1', 'WNS13218'),
#  ('Import_2', 'WNS13397'),
#  ('Import_1', 'WNS13883'),
#  ('Import_1', 'WNS13902'),
#  ('Import_2', 'WNS13525'),
#  ('Import_1', 'WNS13439'),
#  ('Import_2', 'WNS13974'),
#  ('Import_1', 'WNS13510'),
#  ('Import_1', 'WNS13837'),
#  ('Import_1', 'WNS13430'),
#  ('Import_1', 'WNS13561'),
#  ('Import_1', 'WNS13967'),
#  ('Import_1', 'WNS13515'),
#  ('Import_2', 'WNS13960'),
#  ('Import_2', 'WNS13724'),
#  ('Import_2', 'WNS13169'),
#  ('Import_1', 'TSTNDWDE[%]'),
#  ('Import_1', 'WNS13601'),
#  ('Import_1', 'WNS13431'),
#  ('Import_2', 'WNS14017'),
#  ('Import_1', 'WNS14001'),
#  ('Import_1', 'WNS13517'),
#  ('Import_2', 'WNS13751'),
#  ('Import_2', 'WNS13300'),
#  ('Import_2', 'WNS13193'),
#  ('Import_1', 'WNS13894'),
#  ('Import_2', 'WNS13387'),
#  ('Import_1', 'WNS13633'),
#  ('Import_1', 'WNS13412'),
#  ('Import_1', 'WNS13800'),
#  ('Import_2', 'WNS13970'),
#  ('Import_1', 'WNS13572'),
#  ('Import_2', 'WNS13932'),
#  ('Import_1', 'WNS14107'),
#  ('Import_1', 'WNS13197'),
#  ('Import_1', 'WNS13919'),
#  ('Import_1', 'WNS13538'),
#  ('Import_1', 'WNS13142'),
#  ('Import_2', 'WNS13309'),
#  ('Import_1', 'WNS13670'),
#  ('Import_1', 'WNS14121'),
#  ('Import_2', 'WNS14045'),
#  ('Import_2', 'WNS13295'),
#  ('Import_1', 'WNS13495'),
#  ('Import_2', 'WNS13921'),
#  ('Import_1', 'WNS13455'),
#  ('Import_2', 'WNS13378'),
#  ('Import_2', 'WNS13714'),
#  ('Import_2', 'WNS13568'),
#  ('Import_1', 'WNS13969'),
#  ('Import_2', 'WNS13237'),
#  ('Import_2', 'WNS13313'),
#  ('Import_2', 'WNS13667'),
#  ('Import_1', 'WNS14070'),
#  ('Import_2', 'WNS13261'),
#  ('Import_2', 'WNS13179'),
#  ('Import_1', 'WNS13276'),
#  ('Import_2', 'WNS14138'),
#  ('Import_2', 'Ebeo_Bel[DIMSLS]'),
#  ('Import_2', 'WNS13713'),
#  ('Import_1', 'WNS13834'),
#  ('Import_2', 'WNS13357'),
#  ('Import_2', 'WNS13813'),
#  ('Import_1', 'WNS13625'),
#  ('Import_1', 'WNS13991'),
#  ('Import_1', 'WNS13275'),
#  ('Import_1', 'WNS13205'),
#  ('Import_1', 'WNS14022'),
#  ('Import_1', 'WNS13492'),
#  ('Import_2', 'WNS13446'),
#  ('Import_1', 'WNS13742'),
#  ('Import_2', 'WNS13833'),
#  ('Import_1', 'WNS13242'),
#  ('Import_2', 'WNS13987'),
#  ('Import_2', 'WNS13194'),
#  ('Import_1', 'WNS13317'),
#  ('Import_2', 'WNS13889'),
#  ('Import_2', 'WNS13527'),
#  ('Import_2', 'WNS13804'),
#  ('Import_2', 'WNS13735'),
#  ('Import_2', 'WNS14043'),
#  ('Import_2', 'WNS13895'),
#  ('Import_2', 'WNS13978'),
#  ('Import_1', 'WNS13852'),
#  ('Import_1', 'WNS13265'),
#  ('Import_1', 'WNS13615'),
#  ('Import_2', 'WNS13502'),
#  ('Import_2', 'WNS13231'),
#  ('Import_2', 'WNS13712'),
#  ('Import_2', 'WNS13732'),
#  ('Import_1', 'WNS13229'),
#  ('Import_2', 'WNS13784'),
#  ('Import_2', 'WNS13827'),
#  ('Import_2', 'WNS13188'),
#  ('Import_2', 'WNS13306'),
#  ('Import_1', 'WNS13720'),
#  ('Import_1', 'WNS13927'),
#  ('Import_2', 'WNS13861'),
#  ('Import_1', 'WNS13736'),
#  ('Import_1', 'TTSWDE[DIMSLS]'),
#  ('Import_2', 'WNS13810'),
#  ('Import_2', 'WNS14123'),
#  ('Import_1', 'WNS14146'),
#  ('Import_2', 'WNS13549'),
#  ('Import_1', 'WNS13235'),
#  ('Import_2', 'WNS13218'),
#  ('Import_2', 'WNS13902'),
#  ('Import_2', 'WNS13420'),
#  ('Import_2', 'WNS13166'),
#  ('Import_2', 'WNS13480'),
#  ('Import_2', 'WNS13230'),
#  ('Import_2', 'WNS13510'),
#  ('Import_1', 'WNS13423'),
#  ('Import_2', 'WNS13430'),
#  ('Import_2', 'WNS13596'),
#  ('Import_2', 'WNS13515'),
#  ('Import_2', 'WNS14005'),
#  ('Import_2', 'WNS13777'),
#  ('Import_1', 'WNS13458'),
#  ('Import_2', 'WNS13431'),
#  ('Import_1', 'WNS13750'),
#  ('Import_1', 'WNS13842'),
#  ('Import_1', 'WNS13271'),
#  ('Import_2', 'WNS13498'),
#  ('Import_1', 'WNS13563'),
#  ('Import_2', 'WNS14001'),
#  ('Import_1', 'WNS14029'),
#  ('Import_1', 'WNS13282'),
#  ('Import_2', 'WNS13350'),
#  ('Import_2', 'WNS13412'),
#  ('Import_1', 'WNS13368'),
#  ('Import_2', 'WNS13800'),
#  ('Import_2', 'WNS13904'),
#  ('Import_2', 'WNS14107'),
#  ('Import_1', 'WNS14113'),
#  ('Import_2', 'WNS13270'),
#  ('Import_2', 'WNS13437'),
#  ('Import_2', 'WNS13919'),
#  ('Import_2', 'WNS13947'),
#  ('Import_2', 'WNS14121'),
#  ('Import_1', 'WNS13933'),
#  ('Import_1', 'WNS13227'),
#  ('Import_2', 'WNS13455'),
#  ('Import_1', 'WNS13616'),
#  ('Import_1', 'WNS13993'),
#  ('Import_2', 'WNS13354'),
#  ('Import_2', 'WNS13957'),
#  ('Import_1', 'WNS13355'),
#  ('Import_2', 'WNS13570'),
#  ('Import_2', 'WNS14142'),
#  ('Import_1', 'WNS13440'),
#  ('Import_1', 'WNS13886'),
#  ('Import_2', 'WNS13276'),
#  ('Import_2', 'WNS13820'),
#  ('Import_1', 'WNS13598'),
#  ('Import_1', 'WNS13782'),
#  ('Import_1', 'TTSWDE[oC]'),
#  ('Import_2', 'WNS13755'),
#  ('Import_1', 'WNS13802'),
#  ('Import_2', 'WNS13625'),
#  ('Import_2', 'WNS13991'),
#  ('Import_1', 'WNS13836'),
#  ('Import_2', 'WNS13580'),
#  ('Import_2', 'WNS14022'),
#  ('Import_2', 'WNS13757'),
#  ('Import_1', 'WNS13564'),
#  ('Import_1', 'WNS14173'),
#  ('Import_1', 'WNS13645'),
#  ('Import_2', 'WNS13684'),
#  ('Import_2', 'WNS13855'),
#  ('Import_1', 'WNS13559'),
#  ('Import_2', 'WNS13242'),
#  ('Import_1', 'WNS13259'),
#  ('Import_1', 'TTSWDE[n/ml]'),
#  ('Import_1', 'WNS13296'),
#  ('Import_1', 'WNS13465'),
#  ('Import_1', 'WNS13770'),
#  ('Import_1', 'WNS13346'),
#  ('Import_1', 'WNS13536'),
#  ('Import_1', 'TTSWDE[m]'),
#  ('Import_1', 'WNS13303'),
#  ('Import_2', 'WNS13791'),
#  ('Import_2', 'WNS13847'),
#  ('Import_1', 'WNS13603'),
#  ('Import_2', 'WNS13229'),
#  ('Import_1', 'WNS13284'),
#  ('Import_1', 'WNS13610'),
#  ('Import_1', 'WNS13686'),
#  ('Import_1', 'WNS13533'),
#  ('Import_2', 'WNS13720'),
#  ('Import_1', 'WNS13463'),
#  ('Import_2', 'WNS13927'),
#  ('Import_2', 'WNS13736'),
#  ('Import_2', 'TTSWDE[DIMSLS]'),
#  ('Import_2', 'WNS13997'),
#  ('Import_1', 'WNS13560'),
#  ('Import_1', 'WNS13189'),
#  ('Import_2', 'WNS14146'),
#  ('Import_1', 'WNS13758'),
#  ('Import_1', 'WNS13792'),
#  ('Import_2', 'WNS13235'),
#  ('Import_1', 'WNS13187'),
#  ('Import_1', 'WNS14006'),
#  ('Import_2', 'WNS13868'),
#  ('Import_1', 'WNS13168'),
#  ('Import_1', 'WNS13523'),
#  ('Import_1', 'WNS13839'),
#  ('Import_2', 'WNS13689'),
#  ('Import_1', 'WNS14099'),
#  ('Import_2', 'WNS13157'),
#  ('Import_1', 'WNS14097'),
#  ('Import_2', 'WNS13506'),
#  ('Import_2', 'TTSWDE[mg/l]'),
#  ('Import_1', 'WNS14143'),
#  ('Import_1', 'WNS13238'),
#  ('Import_1', 'WNS13806'),
#  ('Import_1', 'WNS13359'),
#  ('Import_1', 'WNS13940'),
#  ('Import_1', 'WNS13949'),
#  ('Import_2', 'WNS13685'),
#  ('Import_1', 'WNS13618'),
#  ('Import_2', 'WNS13458'),
#  ('Import_1', 'WNS13451'),
#  ('Import_2', 'WNS13842'),
#  ('Import_2', 'WNS13271'),
#  ('Import_1', 'WNS13401'),
#  ('Import_2', 'WNS13287'),
#  ('Import_1', 'WNS14026'),
#  ('Import_2', 'WNS14029'),
#  ('Import_1', 'WNS13335'),
#  ('Import_1', 'WNS13691'),
#  ('Import_1', 'WNS13963'),
#  ('Import_2', 'WNS13662'),
#  ('Import_2', 'WNS13368'),
#  ('Import_1', 'WNS13652'),
#  ('Import_2', 'WNS14113'),
#  ('Import_1', 'WNS13976'),
#  ('Import_1', 'WNS13778'),
#  ('Import_2', 'WNS13616'),
#  ('Import_1', 'WNS13901'),
#  ('Import_1', 'WNS14122'),
#  ('Import_2', 'WNS13355'),
#  ('Import_1', 'WNS13630'),
#  ('Import_2', 'WNS13656'),
#  ('Import_1', 'WNS13981'),
#  ('Import_1', 'WNS13353'),
#  ('Import_2', 'WNS13598'),
#  ('Import_2', 'WNS14126'),
#  ('Import_1', 'WNS13953'),
#  ('Import_2', 'TTSWDE[oC]'),
#  ('Import_2', 'WNS13599'),
#  ('Import_1', 'WNS13882'),
#  ('Import_2', 'WNS14173'),
#  ('Import_2', 'WNS13564'),
#  ('Import_1', 'WNS14019'),
#  ('Import_2', 'WNS13645'),
#  ('Import_1', 'WNS13312'),
#  ('Import_2', 'WNS14030'),
#  ('Import_1', 'WNS13793'),
#  ('Import_2', 'WNS13559'),
#  ('Import_2', 'WNS13790'),
#  ('Import_2', 'TTSWDE[n/ml]'),
#  ('Import_2', 'WNS13296'),
#  ('Import_1', 'WNS13469'),
#  ('Import_1', 'TTSWDE[ug/l]'),
#  ('Import_2', 'WNS13816'),
#  ('Import_1', 'WNS13381'),
#  ('Import_2', 'WNS13770'),
#  ('Import_1', 'WNS14012'),
#  ('Import_1', 'WNS13376'),
#  ('Import_2', 'WNS13346'),
#  ('Import_2', 'WNS13731'),
#  ('Import_1', 'WNS14033'),
#  ('Import_2', 'WNS13536'),
#  ('Import_1', 'WNS14124'),
#  ('Import_2', 'WNS13303'),
#  ('Import_2', 'WNS13595'),
#  ('Import_2', 'WNS13467'),
#  ('Import_1', 'WNS13384'),
#  ('Import_1', 'WNS13788'),
#  ('Import_1', 'WNS13180'),
#  ('Import_2', 'WNS13284'),
#  ('Import_2', 'WNS13610'),
#  ('Import_2', 'WNS13593'),
#  ('Import_2', 'WNS13686'),
#  ('Import_1', 'WNS13528'),
#  ('Import_2', 'WNS13533'),
#  ('Import_2', 'WNS13485'),
#  ('Import_2', 'WNS13463'),
#  ('Import_1', 'WNS13626'),
#  ('Import_2', 'WNS13718'),
#  ('Import_1', 'WNS13566'),
#  ('Import_1', 'WNS13934'),
#  ('Import_1', 'WNS13256'),
#  ('Import_2', 'WNS13613'),
#  ('Import_2', 'WNS13756'),
#  ('Import_1', 'TSTNDWDE[n/ml]'),
#  ('Import_1', 'WNS13322'),
#  ('Import_2', 'WNS13758'),
#  ('Import_2', 'WNS13792'),
#  ('Import_1', 'WNS14011'),
#  ('Import_2', 'WNS13187'),
#  ('Import_2', 'WNS13523'),
#  ('Import_1', 'WNS13653'),
#  ('Import_2', 'WNS14099'),
#  ('Import_2', 'WNS13721'),
#  ('Import_2', 'WNS14097'),
#  ('Import_1', 'WNS13375'),
#  ('Import_2', 'WNS13359'),
#  ('Import_1', 'WNS14137'),
#  ('Import_1', 'WNS13251'),
#  ('Import_2', 'WNS13940'),
#  ('Import_1', 'WNS13508'),
#  ('Import_1', 'WNS13575'),
#  ('Import_2', 'WNS13408'),
#  ('Import_2', 'WNS13949'),
#  ('Import_2', 'WNS13618'),
#  ('Import_2', 'WNS13772'),
#  ('Import_1', 'WNS13824'),
#  ('Import_2', 'WNS13401'),
#  ('Import_2', 'WNS13591'),
#  ('Import_2', 'WNS13866'),
#  ('Import_2', 'WNS13341'),
#  ('Import_2', 'WNS13963'),
#  ('Import_2', 'WNS13356'),
#  ('Import_1', 'WNS14151'),
#  ('Import_1', 'WNS13133'),
#  ('Import_2', 'WNS14025'),
#  ('Import_1', 'WNS13922'),
#  ('Import_1', 'WNS13729'),
#  ('Import_1', 'WNS13812'),
#  ('Import_1', 'WNS13592'),
#  ('Import_1', 'WNS13138'),
#  ('Import_1', 'WNS14105'),
#  ('Import_2', 'TTSWDE[%]'),
#  ('Import_1', 'WNS13223'),
#  ('Import_2', 'WNS13976'),
#  ('Import_1', 'WNS14106'),
#  ('Import_2', 'WNS13158'),
#  ...}

# %%
df_2.loc[list(diff_2)]
# Out:
#                              valueType locationSetId       timeSeriesType  \
# moduleInstanceId parameterId
# Import_2         WNS14140       sample   LocationSet  external historical
#                  TTSWDE[n]      sample   LocationSet  external historical
#                  WNS13733       sample   LocationSet  external historical
# Import_1         WNS13895       sample   LocationSet  external historical
#                  WNS13978       sample   LocationSet  external historical
# ...                                ...           ...                  ...
# Import_2         WNS13664       sample   LocationSet  external historical
# Import_1         WNS13194       sample   LocationSet  external historical
# Import_2         WNS13202       sample   LocationSet  external historical
#                  WNS13244       sample   LocationSet  external historical
# Import_1         WNS13527       sample   LocationSet  external historical
#
#                                     timeStep  readWriteMode
# moduleInstanceId parameterId
# Import_2         WNS14140     nonequidistant  add originals
#                  TTSWDE[n]    nonequidistant  add originals
#                  WNS13733     nonequidistant  add originals
# Import_1         WNS13895     nonequidistant  add originals
#                  WNS13978     nonequidistant  add originals
# ...                                      ...            ...
# Import_2         WNS13664     nonequidistant  add originals
# Import_1         WNS13194     nonequidistant  add originals
# Import_2         WNS13202     nonequidistant  add originals
#                  WNS13244     nonequidistant  add originals
# Import_1         WNS13527     nonequidistant  add originals
#
# [1982 rows x 5 columns]

# %%
output_to_xml(root_2, diff_2, output_file="diff_2.xml")

# %% [markdown]
# format file with:<br>
#     extension: `pretty XML`<br>
#     and Vscode user settings:<br>
#
#         ```json
#          "prettyxml.settings.addSpaceBeforeSelfClosingTag": false,
#         "prettyxml.settings.attributesInNewlineThreshold": 9,
#         "prettyxml.settings.positionAllAttributesOnFirstLine": true,
#         "prettyxml.settings.preserveWhiteSpacesInComment": true,
#         "editor.insertSpaces": true,
#         "[xml]": {
#         "editor.defaultFormatter": "PrateekMahendrakar.prettyxml"
#         },
#         ```
