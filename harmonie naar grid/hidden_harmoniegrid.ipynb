# %%
import xarray as xr

# %%
ds = xr.open_dataset("datasets/wiwb9687401185919889317.nc")

# %%
ax = ds.isel(analysis_time=0, time=20)['APCP'].plot()

# %%
ds.isel(analysis_time=0, time=20)
# Out:
# <xarray.Dataset> Size: 8kB
# Dimensions:        (x: 48, y: 38)
# Coordinates:
#     analysis_time  datetime64[ns] 8B 2024-10-25T10:00:00
#   * x              (x) float64 384B 5.133 5.162 5.191 5.22 ... 6.438 6.467 6.496
#   * y              (y) float64 304B 52.56 52.55 52.53 52.51 ... 51.93 51.92 51.9
#     time           datetime64[ns] 8B 2024-10-26T06:00:00
# Data variables:
#     crs            int32 4B ...
#     APCP           (y, x) float32 7kB ...
# Attributes:
#     Conventions:           CF-1.6
#     title:                 Data
#     institution:           HydroLogic B.V.
#     source:                HydroNET 4 Server
#     history:               2024-10-25 13:43:48 UTC: exported from HydroNET 4 ...
#     references:            http://www.hydrologic.com/
#     Metadata_Conventions:  Unidata Dataset Discovery v1.0
#     summary:               Data exported from HydroNET 4 Server
#     date_created:          2024-10-25 13:43:48 UTC

# %%
x = ds.isel(analysis_time=0, time=20,y=0)['x'].values
x_0 = x[0]
x_0
# Out:
# 5.133

# %%
dx = abs(x[1] - x[0])
dx
# Out:
# 0.028999999999999915

# %%
y = ds.isel(analysis_time=0, time=20,x=0)['y'].values
y_0 = y[0]
y_0
# Out:
# 52.564

# %%
dy = abs(y[1] - y[0])
dy
# Out:
# 0.018000000000000682

# %%
rows = len(x)
columns = len(y)

# %%
print(f'<regular locationId="WIWB-HARMONIE">\n\
		<rows>{rows}</rows>\n\
		<columns>{columns}</columns>\n\
		<geoDatum>WGS 1984</geoDatum>\n\
		<firstCellCenter>\n\
			<x>{x_0}</x>\n\
			<y>{y_0}</y>\n\
		</firstCellCenter>\n\
		<xCellSize>{dx}</xCellSize>\n\
		<yCellSize>{dy}</yCellSize>\n\
	</regular>')
# Out:
# <regular locationId="WIWB-HARMONIE">
# 		<rows>48</rows>
# 		<columns>38</columns>
# 		<geoDatum>WGS 1984</geoDatum>
# 		<firstCellCenter>
# 			<x>5.133</x>
# 			<y>52.564</y>
# 		</firstCellCenter>
# 		<xCellSize>0.028999999999999915</xCellSize>
# 		<yCellSize>0.018000000000000682</yCellSize>
# 	</regular>
