# %%
import xarray as xr

# %%
filename='wiwb2993127316874942550.nc'

# %%
ds = xr.open_dataset(filename)

# %%
ds

# %%
ys = ds.isel(time=0, analysis_time=0,)['y'].values
ys

# %%
ys[1] - ys[0]

# %%
xs = ds.isel(time=0, analysis_time=0,)['x'].values
xs

# %%
xs[1] - xs[0]
